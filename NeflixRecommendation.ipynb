# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set = pd.read_csv('./8. Netflix Dataset.csv')

# %%
data_set.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data_set.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
data_set.describe()
# Out:
#        Show_Id Category              Title                Director  \
# count     7789     7789               7789                    5401
# unique    7787        2               7787                    4050
# top      s6621    Movie  The Lost Okoroshi  Raúl Campos, Jan Suter
# freq         2     5379                  2                      18
#
#                       Cast        Country     Release_Date Rating  Duration  \
# count                 7071           7282             7779   7782      7789
# unique                6831            681             1565     14       216
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    18           2556              118   2865      1608
#
#                  Type                                        Description
# count            7789                                               7789
# unique            492                                               7769
# ...

# %%
data_set.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
data_set[data_set.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data_set.drop_duplicates(inplace=True)

# %%
data_set.isnull().head(2)
# Out:
#    Show_Id  Category  Title  Director   Cast  Country  Release_Date  Rating  \
# 0    False     False  False      True  False    False         False   False
# 1    False     False  False     False  False    False         False   False
#
#    Duration   Type  Description
# 0     False  False        False
# 1     False  False        False

# %%
sns.heatmap(data_set.isnull())
# Out:
# <AxesSubplot:>

# %%
missing_values = ['NONE', 'None', 'none', 'NAN', 'Nan', 'nan', 'n/a', 'na', '']
null_values = pd.read_csv('./8. Netflix Dataset.csv',  na_values = missing_values)
null_values.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
data_set.shape
# Out:
# (7787, 11)

# %%
data_set.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %% [markdown]
# isIn() function is used to find the particular data in the Dataframe

# %%
data_set['Title'].head(2)
# Out:
# 0       3%
# 1    07:19
# Name: Title, dtype: object

# %%
data_set[data_set['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data_set[data_set['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data_set.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data_set['Movies_Res'] = pd.to_datetime(data_set['Release_Date'])

# %%
data_set.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Movies_Res
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data_set.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Movies_Res      datetime64[ns]
# dtype: object

# %%
data_set['Movies_Res'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Movies_Res, dtype: int64

# %% [markdown]
# Show the Release Date in Plot

# %%
data_set['Movies_Res'].dt.year.value_counts().plot(kind='bar').set_title('Year Distribution')
# Out:
# Text(0.5, 1.0, 'Year Distribution')

# %%
data_set['Movies_Res'].dt.month.value_counts()
# Out:
# 12.0    833
# 10.0    785
# 1.0     757
# 11.0    738
# 3.0     669
# 9.0     619
# 8.0     618
# 4.0     601
# 7.0     600
# 5.0     543
# 6.0     542
# 2.0     472
# Name: Movies_Res, dtype: int64

# %%
data_set['Movies_Res'].dt.month.value_counts().plot(kind='bar').set_xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
data_set['Movies_Res'].dt.weekday.value_counts()
# Out:
# 4.0    2287
# 3.0    1147
# 1.0    1070
# 2.0    1020
# 0.0     814
# 5.0     731
# 6.0     708
# Name: Movies_Res, dtype: int64

# %%
data_set['Movies_Res'].dt.weekday.value_counts().plot(kind='bar', x='weekday', y='count').set_xlabel('Weekday')
# Out:
# Text(0.5, 0, 'Weekday')

# %% [markdown]
# Groupby() function to count MOVIES and TV SHOW in the column

# %%
data_set.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Movies_Res
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %% [markdown]
# data_set.groupby('Category').count() will count all the columns values. But if we want to count only in Category column what we can do.

# %%
data_set.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
data_set.groupby('Category').count()
# Out:
#           Show_Id  Title  Director  Cast  Country  Release_Date  Rating  \
# Category
# Movie        5377   5377      5214  4951     5147          5377    5372
# TV Show      2410   2410       185  2118     2133          2400    2408
#
#           Duration  Type  Description  Movies_Res
# Category
# Movie         5377  5377         5377        5377
# TV Show       2410  2410         2410        2400

# %%
data_set['Country'].value_counts()
# Out:
# United States                                                   2555
# India                                                            923
# United Kingdom                                                   397
# Japan                                                            226
# South Korea                                                      183
#                                                                 ...
# Russia, United States, China                                       1
# Italy, Switzerland, France, Germany                                1
# United States, United Kingdom, Canada                              1
# United States, United Kingdom, Japan                               1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Name: Country, Length: 681, dtype: int64

# %%
sns.countplot(data_set['Category'])
# Out:
# c:\Users\Irfan Wahab Khattak\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
data_set['Year'] = data_set['Movies_Res'].dt.year

# %%
data_set.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Movies_Res    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %% [markdown]
# For checking MOVIES that is released in 2000 to 2020

# %%
data_set[(data_set['Category'] == 'Movie') & (data_set['Country'] == 'United States')]['Title'].head(20)
# Out:
# 3                                            9
# 4                                           21
# 7                                          187
# 10                                        1922
# 14                                        3022
# 25                                    (T)ERROR
# 33                                #realityhigh
# 35                                   #Rucker50
# 44                                    Æon Flux
# 46                            1 Chance 2 Dance
# 47                               1 Mile to You
# 55         100 Things to do Before High School
# 56    100 Years: One Woman's Fight for Justice
# 60                                12 ROUND GUN
# 62                                  13 Cameras
# 65                                     13 Sins
# 66                                        13TH
# 69                                  14 Cameras
# 70                       14 Minutes from Earth
# 72                                    17 Again
# ...

# %% [markdown]
# Top 10 Directors

# %%
data_set['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# Movies with category HORROR

# %%
data_set[(data_set['Type'] == 'Horror Movies')]
# Out:
#      Show_Id Category                         Title  \
# 261     s262    Movie                        A.M.I.
# 417     s418    Movie  All the Boys Love Mandy Lane
# 1551   s1552    Movie                Cult of Chucky
# 1654   s1655    Movie                       Deadcon
# 1671   s1672    Movie                   Death House
# 1673   s1674    Movie                   Death of Me
# 1811   s1812    Movie   Don't Be Afraid of the Dark
# 1976   s1977    Movie                           Eli
# 2104   s2105    Movie                  Family Blood
# 2165   s2166    Movie           Final Destination 3
# 2286   s2287    Movie               Friday the 13th
# 2394   s2395    Movie                   Ghost House
# 2405   s2406    Movie                 Ghosts of War
# 2422   s2423    Movie       Girl on the Third Floor
# 2704   s2705    Movie                    Here Alone
# 2833   s2834    Movie            House of the Witch
# 3456   s3457    Movie                        Kristy
# ...

# %% [markdown]
# Commedy movies from specific country

# %%
data_set[(data_set['Category'] == 'Movie') & (data_set['Type'] == 'Horro Movies') | (data_set['Country'] == 'United States')]
# Out:
#      Show_Id Category                       Title         Director  \
# 3         s4    Movie                           9      Shane Acker
# 4         s5    Movie                          21   Robert Luketic
# 7         s8    Movie                         187   Kevin Reynolds
# 10       s11    Movie                        1922     Zak Hilditch
# 14       s15    Movie                        3022       John Suits
# ...      ...      ...                         ...              ...
# 7760   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 7773   s7772    Movie                        Zion       Floyd Russ
# 7776   s7775    Movie                      Zodiac    David Fincher
# 7780   s7779    Movie                  Zombieland  Ruben Fleischer
# 7783   s7782    Movie                        Zoom     Peter Hewitt
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %% [markdown]
# Number of movies and tv shows released countrywise

# %%
data_set['Country'].value_counts().head(10).plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
data_set.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# Most appeared cast

# %%
data_set['Cast'].value_counts().head(10).plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Cast'>

# %% [markdown]
# How many tv shows or movies TOM CRUISE play a role

# %%
data_set[data_set['Cast'] == 'Tom Cruise']
#it's a list of names where Tom Cruise is not present. let's try another way to find the Tom Cruise name
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Movies_Res, Year]
# Index: []

# %% [markdown]
# Going to use str.countain() method. !str.countain is going to work with null values so we have to remove or drop the null values from the columns.

# %%
data_set[data_set['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\IRFANW~1\AppData\Local\Temp/ipykernel_11316/2412167957.py in <module>
# ----> 1 data_set[data_set['Cast'].str.contains('Tom Cruise')]
#
# c:\Users\Irfan Wahab Khattak\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3493
#    3494         # Do we have a (boolean) 1d indexer?
# -> 3495         if com.is_bool_indexer(key):
#    3496             return self._getitem_bool_array(key)
#    3497
#
# c:\Users\Irfan Wahab Khattak\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     142                     # Don't raise on e.g. ["A", "B", np.nan], see
#     143                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 144                     raise ValueError(na_msg)
# ...

# %% [markdown]
# Using dropna() function to remove the null values from the cast column

# %%
data_set_null = data_set.dropna()

# %%
data_set_null.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description Movies_Res    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
data_set_null[data_set_null['Cast'].str.contains('Tom Cruise')].head(2)
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description Movies_Res    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# TV Shows and Movies Netflix rating !We are going to use nunique() and unique() function.

# %%
data_set['Rating'].nunique()
# Out:
# 14

# %%
data_set['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
data_set['Rating'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# TV-14 Rating in CANADA

# %%
data_set.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Movies_Res    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data_set[(data_set['Category'] == 'Movie') & (data_set['Rating'] == 'TV-14')].head(4)
# Out:
#    Show_Id Category                 Title            Director  \
# 8       s9    Movie                   706       Shravan Kumar
# 15     s16    Movie                Oct-01      Kunle Afolayan
# 18     s19    Movie                15-Aug  Swapnaneel Jayakar
# 20     s21    Movie  ​​Kuch Bheege Alfaaz                Onir
#
#                                                  Cast  Country  \
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...    India
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...  Nigeria
# 18  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...    India
# 20  Geetanjali Thapa, Zain Khan Durrani, Shray Rai...    India
#
#          Release_Date Rating Duration  \
# 8       April 1, 2019  TV-14  118 min
# 15  September 1, 2019  TV-14  149 min
# 18     March 29, 2019  TV-14  124 min
# 20  September 1, 2018  TV-14  110 min
#
#                                                 Type  \
# 8                Horror Movies, International Movies
# ...

# %%
data_set[(data_set['Category'] == 'Movie') & (data_set['Rating'] == 'TV-14') & (data_set['Country'] == 'Pakistan')]
# Out:
#      Show_Id Category                        Title            Director  \
# 282     s283    Movie  Abdullah, The Final Witness  Hashim Nadeem Khan
# 1263   s1264    Movie            Chalay Thay Saath           Umer Adil
# 1384   s1385    Movie                Chupan Chupai          Mohsin Ali
# 3120   s3121    Movie                       Janaan         Azfar Jafri
# 4775   s4776    Movie                         Pari       Syed Atif Ali
# 5101   s5101    Movie                     Rangreza      Amir Mohiuddin
# 5329   s5329    Movie                       Saawan         Farhan Alam
# 6008   s6008    Movie             Teefa in Trouble         Ahsan Rahim
# 7677   s7676    Movie                    Wrong No.         Yasir Nawaz
# 7770   s7769    Movie     Zindagi Kitni Haseen Hay       Anjum Shahzad
#
#                                                    Cast   Country  \
# 282   Sajid Hasan, Hameed Sheikh, Habibullah Panezai...  Pakistan
# ...

# %% [markdown]
# Duration of the Movies and the Tv Shows on Netflix

# %%
data_set.Duration.nunique()
# Out:
# 216

# %%
data_set.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data_set.Duration.dtypes
# Out:
# dtype('O')

# %% [markdown]
# Create two different columns one for duration and other for label

# %%
data_set[['Minutes', 'Unit']] = data_set['Duration'].str.split(n=1, expand=True)
data_set.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description Movies_Res    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
#
#   Minutes     Unit
# 0       4  Seasons

# %% [markdown]
# m
